# %% [markdown]
# # **Langkah 1. Pemuatan dan Inspeksi Data**

# %% [markdown]
# Mengimpor dataset dan melihat 5 data awal

# %%
import pandas as pd
import numpy as np

data = "https://raw.githubusercontent.com/Faris0520/filecolab/refs/heads/main/Data%20Mining/katalog_gempa.csv"
df = pd.read_csv(data)
df.head()
# Out:
# /tmp/ipython-input-2626548412.py:5: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(data)
#        eventID                          datetime  latitude   longitude  \
# 0  bmg2008vkye  2008-11-01 00:31:25.143741+00:00 -0.604440   98.895531
# 1  bmg2008vlag  2008-11-01 01:34:29.660856+00:00 -6.611860  129.387220
# 2  bmg2008vlaj  2008-11-01 01:38:14.802129+00:00 -3.650586  127.990680
# 3  bmg2008vlbt  2008-11-01 02:20:05.909515+00:00 -4.198925  128.097000
# 4  bmg2008vlcd  2008-11-01 02:32:18.756155+00:00 -4.091891  128.200470
#
#    magnitude mag_type  depth  phasecount  azimuth_gap  \
# 0   2.989742      MLv     20         6.0    146.70738
# 1   5.507549       mb     30        62.0     45.46764
# 2   3.539674      MLv      5         4.0    331.97404
# 3   2.424314      MLv      5         5.0    326.37993
# 4   2.410045      MLv     10         5.0    314.65474
#
#                       location  ... doubleCouple clvd  strikeNP1  dipNP1  \
# 0  Southern Sumatra, Indonesia  ...          NaN  NaN        NaN     NaN
# 1                    Banda Sea  ...          NaN  NaN        NaN     NaN
# 2             Seram, Indonesia  ...          NaN  NaN        NaN     NaN
# 3                    Banda Sea  ...          NaN  NaN        NaN     NaN
# 4                    Banda Sea  ...          NaN  NaN        NaN     NaN
#
#    rakeNP1 strikeNP2  dipNP2  rakeNP2  azgapFM  misfit
# 0      NaN       NaN     NaN      NaN      NaN     NaN
# 1      NaN       NaN     NaN      NaN      NaN     NaN
# 2      NaN       NaN     NaN      NaN      NaN     NaN
# 3      NaN       NaN     NaN      NaN      NaN     NaN
# 4      NaN       NaN     NaN      NaN      NaN     NaN
#
# [5 rows x 37 columns]

# %% [markdown]
# Melihat informasi dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131833 entries, 0 to 131832
# Data columns (total 37 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0    eventID           131833 non-null  object
#  1   datetime           131833 non-null  object
#  2   latitude           131833 non-null  float64
#  3   longitude          131833 non-null  float64
#  4   magnitude          131134 non-null  float64
#  5   mag_type           131134 non-null  object
#  6   depth              131833 non-null  int64
#  7   phasecount         131831 non-null  float64
#  8   azimuth_gap        131829 non-null  float64
#  9   location           131817 non-null  object
#  10  agency             128390 non-null  object
#  11  datetimeFM         4607 non-null    object
#  12  latFM              4607 non-null    float64
#  13  lonFM              4607 non-null    float64
#  14  magFM              3908 non-null    float64
#  15  magTypeFM          3908 non-null    object
#  16  depthFM            4607 non-null    float64
#  17  phasecountFM       4607 non-null    float64
#  18  AzGapFM            4452 non-null    float64
#  19  scalarMoment       4452 non-null    float64
#  20  Mrr                4452 non-null    float64
#  21  Mtt                4452 non-null    float64
#  22  Mpp                4452 non-null    float64
#  23  Mrt                4452 non-null    float64
#  24  Mrp                4452 non-null    float64
#  25  Mtp                4452 non-null    float64
#  26  varianceReduction  4449 non-null    float64
#  27  doubleCouple       4452 non-null    float64
#  28  clvd               4452 non-null    float64
#  29  strikeNP1          4607 non-null    float64
#  30  dipNP1             4607 non-null    float64
#  31  rakeNP1            4607 non-null    float64
#  32  strikeNP2          4607 non-null    float64
#  33  dipNP2             4607 non-null    float64
#  34  rakeNP2            4607 non-null    float64
#  35  azgapFM            4452 non-null    float64
#  36  misfit             4447 non-null    float64
# dtypes: float64(29), int64(1), object(7)
# memory usage: 37.2+ MB

# %% [markdown]
# # **Langkah 2. Menyortir Data**

# %% [markdown]
# Kode ini untuk milih kolom,
# lalu di sort menurut datetime, lalu di sort lagi hanya sampai 30000 baris, dan menghasilkan file hasil_sort.csv

# %%
kolom_sort = df.sort_values(by='datetime', ascending=False)
kolom = kolom_sort.iloc[2600:32600, 0:10]

kolom.to_csv('hasil_sort.csv', index=False)

# %% [markdown]
# # **Langkah 3. Menangani Missing Value**

# %% [markdown]
# Impor lagi data bersih tadi.

# %%
import pandas as pd
import numpy as np
databersih = 'https://raw.githubusercontent.com/Faris0520/filecolab/refs/heads/main/Data%20Mining/hasil_sort.csv'
df = pd.read_csv(databersih)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0    eventID     30000 non-null  object
#  1   datetime     30000 non-null  object
#  2   latitude     30000 non-null  float64
#  3   longitude    30000 non-null  float64
#  4   magnitude    29836 non-null  float64
#  5   mag_type     29836 non-null  object
#  6   depth        30000 non-null  int64
#  7   phasecount   30000 non-null  float64
#  8   azimuth_gap  30000 non-null  float64
#  9   location     29988 non-null  object
# dtypes: float64(5), int64(1), object(4)
# memory usage: 2.3+ MB

# %% [markdown]
# Menampilkan 5 data awal

# %%
df.head()
# Out:
#        eventID                          datetime  latitude   longitude  \
# 0  bmg2025qdxk  2025-08-18 19:48:26.962797+00:00  4.818060   96.788818
# 1  bmg2025qdxa  2025-08-18 19:36:15.909379+00:00 -6.035361  103.826210
# 2  bmg2025qdwx  2025-08-18 19:32:48.184130+00:00 -1.358739  120.642342
# 3  bmg2025qdwp  2025-08-18 19:23:32.255045+00:00  1.029507  125.595398
# 4  bmg2025qdwi  2025-08-18 19:15:55.688019+00:00  1.025022  125.596230
#
#    magnitude mag_type  depth  phasecount  azimuth_gap  \
# 0   1.796840      MLv      5        13.0   110.303917
# 1   2.371711      MLv      8        17.0   269.408211
# 2   1.359980      MLv      5        12.0   201.413223
# 3   2.604023      MLv     37         8.0   261.772003
# 4   2.990525      MLv     40        10.0   262.022034
#
#                           location
# 0      Northern Sumatra, Indonesia
# 1  Southwest of Sumatra, Indonesia
# 2              Sulawesi, Indonesia
# 3             Northern Molucca Sea
# 4             Northern Molucca Sea

# %% [markdown]
# Mencari missing value

# %%
print("Jumlah missing value:")
print(df.isnull().sum())
# Out:
# Jumlah missing value:
#  eventID         0
# datetime         0
# latitude         0
# longitude        0
# magnitude      164
# mag_type       164
# depth            0
# phasecount       0
# azimuth_gap      0
# location        12
# dtype: int64

# %% [markdown]
# Isi missing value

# %%
df_filled = df.copy()

# Kategorikal
for col in df_filled.select_dtypes(include='object').columns:
  df_filled[col] = df_filled[col].fillna(df_filled[col].mode()[0])

# Numerikal
for col in df_filled.select_dtypes(include=[np.number]).columns:
  df_filled[col] = df_filled[col].fillna(df_filled[col].median())

print("\nJumlah Missing Value per kolom:")
print(df_filled.isnull().sum())

df = df_filled
# Out:
# Jumlah Missing Value per kolom:
#  eventID       0
# datetime       0
# latitude       0
# longitude      0
# magnitude      0
# mag_type       0
# depth          0
# phasecount     0
# azimuth_gap    0
# location       0
# dtype: int64

# %% [markdown]
# Cari Outlier

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.boxplot(x = df["phasecount"])
# Out:
# <Axes: xlabel='phasecount'>

# %%
sns.boxplot(x = df["depth"])
# Out:
# <Axes: xlabel='depth'>

# %% [markdown]
# Menghapus Outlier

# %%
kolomNumerik = ["phasecount", "depth"]

df_clean = df.dropna().copy()

for col in kolomNumerik:
    Q1 = df_clean[col].quantile(0.25)
    Q3 = df_clean[col].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    df_clean = df_clean[
        (df_clean[col] >= lower) &
        (df_clean[col] <= upper)
    ]

    print(f"\nKolom: {col}")
    print(f"Lower: {lower:.2f}, Upper: {upper:.2f}")
    print("Sisa data:", df_clean.shape[0])
# Out:
# Kolom: phasecount
# Lower: -16.50, Upper: 67.50
# Sisa data: 24317
#
# Kolom: depth
# Lower: -15.50, Upper: 52.50
# Sisa data: 21634

# %%
# Cek hasil
print("Jumlah data setelah filter:", len(df))
print("Magnitudo minimum sekarang:", df['magnitude'].min())
print("Magnitudo maksimum sekarang:", df['magnitude'].max())
# Out:
# Jumlah data setelah filter: 25981
# Magnitudo minimum sekarang: 0.191152960643975
# Magnitudo maksimum sekarang: 7.598048456

# %%
df_clean.to_csv("gempa_clean.csv", index=False)

# %%
sns.boxplot(x=df_clean["phasecount"])
# Out:
# <Axes: xlabel='phasecount'>

# %% [markdown]
# Visualisasi Hasil Sementara

# %%
plt.figure(figsize=(10,5))
sns.histplot(df_clean['magnitude'], bins=30, kde=True)
plt.title('Distribusi Magnitudo Gempa di Indonesia (2023–2025)')
plt.xlabel('Magnitudo')
plt.ylabel('Frekuensi')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x='longitude', y='latitude', hue='magnitude', data=df_clean, palette='grey', s=10)
plt.title('Sebaran Lokasi Gempa di Indonesia')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %% [markdown]
# # **Langkah 4. Klasifikasi Magnitudo**

# %% [markdown]
# Klasifikasi kelas magnitudo

# %%
df = pd.read_csv("gempa_clean.csv")
def kategori_magnitude(m):
    if m < 3.0:
        return 'Ringan'
    elif 3.0 <= m < 5.0:
        return 'Sedang'
    else:
        return 'Kuat'

df['kategori_magnitude'] = df['magnitude'].apply(kategori_magnitude)
df.tail()
# Out:
#            eventID                          datetime  latitude   longitude  \
# 21629  bmg2023aclx  2023-01-02 08:17:28.456937+00:00 -2.216316  140.800873
# 21630  bmg2023acle  2023-01-02 07:55:11.766586+00:00 -2.520355  140.711029
# 21631  bmg2023ackl  2023-01-02 07:32:27.231316+00:00 -2.423716  140.757660
# 21632  bmg2023acke  2023-01-02 07:24:12.954644+00:00  0.842975   97.386780
# 21633  bmg2023acjg  2023-01-02 06:56:43.213556+00:00 -2.391350  140.783096
#
#        magnitude mag_type  depth  phasecount  azimuth_gap  \
# 21629   2.786536        M     10         8.0   305.074432
# 21630   3.315733        M     10         9.0   223.591934
# 21631   2.681721        M     10         8.0   287.120361
# 21632   2.750188        M     21        10.0   190.801712
# 21633   2.697630        M     10         8.0   292.044190
#
#                              location kategori_magnitude
# 21629  Near North Coast of West Papua             Ringan
# 21630  Near North Coast of West Papua             Sedang
# 21631  Near North Coast of West Papua             Ringan
# 21632     Northern Sumatra, Indonesia             Ringan
# 21633  Near North Coast of West Papua             Ringan

# %% [markdown]
# Normalisasi Kategorikal menggunakan LabelEncoder

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['mag_type_encoded'] = le.fit_transform(df['mag_type'])
df
# Out:
#            eventID                          datetime  latitude   longitude  \
# 0      bmg2025qdxk  2025-08-18 19:48:26.962797+00:00  4.818060   96.788818
# 1      bmg2025qdxa  2025-08-18 19:36:15.909379+00:00 -6.035361  103.826210
# 2      bmg2025qdwx  2025-08-18 19:32:48.184130+00:00 -1.358739  120.642342
# 3      bmg2025qdwp  2025-08-18 19:23:32.255045+00:00  1.029507  125.595398
# 4      bmg2025qdwi  2025-08-18 19:15:55.688019+00:00  1.025022  125.596230
# ...            ...                               ...       ...         ...
# 21629  bmg2023aclx  2023-01-02 08:17:28.456937+00:00 -2.216316  140.800873
# 21630  bmg2023acle  2023-01-02 07:55:11.766586+00:00 -2.520355  140.711029
# 21631  bmg2023ackl  2023-01-02 07:32:27.231316+00:00 -2.423716  140.757660
# 21632  bmg2023acke  2023-01-02 07:24:12.954644+00:00  0.842975   97.386780
# 21633  bmg2023acjg  2023-01-02 06:56:43.213556+00:00 -2.391350  140.783096
#
#        magnitude mag_type  depth  phasecount  azimuth_gap  \
# 0       1.796840      MLv      5        13.0   110.303917
# 1       2.371711      MLv      8        17.0   269.408211
# 2       1.359980      MLv      5        12.0   201.413223
# 3       2.604023      MLv     37         8.0   261.772003
# 4       2.990525      MLv     40        10.0   262.022034
# ...          ...      ...    ...         ...          ...
# 21629   2.786536        M     10         8.0   305.074432
# 21630   3.315733        M     10         9.0   223.591934
# 21631   2.681721        M     10         8.0   287.120361
# 21632   2.750188        M     21        10.0   190.801712
# 21633   2.697630        M     10         8.0   292.044190
#
#                               location kategori_magnitude  mag_type_encoded
# 0          Northern Sumatra, Indonesia             Ringan                 2
# 1      Southwest of Sumatra, Indonesia             Ringan                 2
# 2                  Sulawesi, Indonesia             Ringan                 2
# 3                 Northern Molucca Sea             Ringan                 2
# 4                 Northern Molucca Sea             Ringan                 2
# ...                                ...                ...               ...
# 21629   Near North Coast of West Papua             Ringan                 0
# 21630   Near North Coast of West Papua             Sedang                 0
# 21631   Near North Coast of West Papua             Ringan                 0
# 21632      Northern Sumatra, Indonesia             Ringan                 0
# 21633   Near North Coast of West Papua             Ringan                 0
#
# [21634 rows x 12 columns]

# %% [markdown]
# Normalisasi numerik dengan Min-Max

# %%
from sklearn.preprocessing import MinMaxScaler

features = ['latitude', 'longitude', 'depth', 'phasecount', 'azimuth_gap', 'mag_type_encoded']

X = df[features].copy()
y = df['kategori_magnitude']

scaler = MinMaxScaler()
X[['latitude', 'longitude', 'depth', 'phasecount', 'azimuth_gap']] = scaler.fit_transform(
    X[['latitude', 'longitude', 'depth', 'phasecount', 'azimuth_gap']]
)

X[['latitude', 'longitude', 'depth', 'phasecount', 'azimuth_gap']].head()
# Out:
#    latitude  longitude     depth  phasecount  azimuth_gap
# 0  0.930488   0.038618  0.078431    0.194030     0.306400
# 1  0.291598   0.191653  0.137255    0.253731     0.748356
# 2  0.566889   0.557338  0.078431    0.179104     0.559481
# 3  0.707474   0.665048  0.705882    0.119403     0.727144
# 4  0.707210   0.665066  0.764706    0.149254     0.727839

# %% [markdown]
# # **Langkah 5. Training model**

# %%
# Import library tambahan
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# Load data hasil cleaning (dari langkah sebelumnya)
df = pd.read_csv("gempa_clean.csv")

# Encode fitur kategorikal
le_magtype = LabelEncoder()
df['mag_type_encoded'] = le_magtype.fit_transform(df['mag_type'])
df['kategori_magnitude'] = df['magnitude'].apply(kategori_magnitude)

le_location = LabelEncoder()
df['location_encoded'] = le_location.fit_transform(df['location'])

# Pilih fitur dan target
features = ['latitude', 'longitude', 'depth', 'phasecount', 'azimuth_gap', 'mag_type_encoded']
X = df[features].copy()
y = df['kategori_magnitude']

# Normalisasi fitur numerik
scaler = MinMaxScaler()
X[['latitude', 'longitude', 'depth', 'phasecount', 'azimuth_gap']] = scaler.fit_transform(
    X[['latitude', 'longitude', 'depth', 'phasecount', 'azimuth_gap']]
)

# Split data latih dan uji
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, stratify=y, random_state=42)

# Bangun model Naïve Bayes
model = GaussianNB()
model.fit(X_train, y_train)

# Prediksi
y_pred = model.predict(X_test)

# Evaluasi
acc = accuracy_score(y_test, y_pred)

# %% [markdown]
# Hasil Klasifikasi

# %%
print(f"Akurasi: {acc:.4f}")
print("Classification Report:")
print(classification_report(y_test, y_pred))

print("Confusion Matrix:")
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# Akurasi: 0.7146
# Classification Report:
#               precision    recall  f1-score   support
#
#         Kuat       0.12      0.17      0.14         6
#       Ringan       0.68      0.79      0.73      2071
#       Sedang       0.77      0.65      0.70      2250
#
#     accuracy                           0.71      4327
#    macro avg       0.52      0.53      0.52      4327
# weighted avg       0.72      0.71      0.71      4327
#
# Confusion Matrix:
# [[   1    1    4]
#  [   0 1631  440]
#  [   7  783 1460]]

# %%
print("Jumlah data latih :", X_train.shape[0])
print("Jumlah data uji   :", X_test.shape[0])
# Out:
# Jumlah data latih : 17307
# Jumlah data uji   : 4327

# %% [markdown]
# Grafik Confusion Matrix

# %%
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel("Prediksi")
plt.ylabel("Aktual")
plt.title("Confusion Matrix Naïve Bayes")
plt.show()

# %%
df.to_csv("gempa_final.csv", index=False)
